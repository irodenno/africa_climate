# %%
from sklearn.datasets import fetch_california_housing

# %%
california_housing = fetch_california_housing(as_frame=True).frame

# %%
california_housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
california_housing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
 import seaborn as sns

# %%
sns.histplot(california_housing ["MedHouseVal"])
# Out:
# <Axes: xlabel='MedHouseVal', ylabel='Count'>

# %%
cal_skew=(california_housing.skew())
cal_skew
# Out:
# MedInc          1.646657
# HouseAge        0.060331
# AveRooms       20.697869
# AveBedrms      31.316956
# Population      4.935858
# AveOccup       97.639561
# Latitude        0.465953
# Longitude      -0.297801
# MedHouseVal     0.977763
# dtype: float64

# %%
q1 = california_housing["MedHouseVal"].quantile(0.25)
q3 = california_housing["MedHouseVal"].quantile(0.75)
iqr = q3 -q1

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = california_housing[(california_housing['MedHouseVal'] < lower_bound) | (california_housing['MedHouseVal'] > upper_bound)]
outliers
# Out:
#         MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 89      1.2434      52.0  2.929412   0.917647       396.0  4.658824     37.80
# 140     6.3624      30.0  5.615385   0.730769       126.0  2.423077     37.81
# 459     1.1696      52.0  2.436000   0.944000      1349.0  5.396000     37.87
# 489     3.0417      48.0  4.690632   1.126362      1656.0  3.607843     37.86
# 493     7.8521      52.0  7.794393   1.051402       517.0  2.415888     37.86
# ...        ...       ...       ...        ...         ...       ...       ...
# 20422   5.1457      35.0  6.958333   1.217593       576.0  2.666667     34.14
# 20426  10.0472      11.0  9.890756   1.159664       415.0  3.487395     34.18
# 20427   8.6499       4.0  7.236059   1.032528      5495.0  2.553439     34.19
# 20436  12.5420      10.0  9.873315   1.102426      1179.0  3.177898     34.21
# 20443   3.3438      50.0  5.342857   0.942857       130.0  3.714286     34.27
#
#        Longitude  MedHouseVal
# ...

# %%
matrix= california_housing.corr()
matrix
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
sns.heatmap(matrix,vmin=-1,vmax=1 )
# Out:
# <Axes: >

# %%
sns.scatterplot(data=california_housing,x="MedInc" ,y="MedHouseVal")
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %%
from sklearn.model_selection import train_test_split

# %%
X=california_housing[["MedInc"]]
Y=california_housing[["MedHouseVal"]]

X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.2, random_state=42)

# %%
type(X_train)
# Out:
# pandas.DataFrame

# %%
X_train.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16512 entries, 14196 to 15795
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MedInc  16512 non-null  float64
# dtypes: float64(1)
# memory usage: 258.0 KB

# %%
X_test.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4128 entries, 20046 to 3665
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MedInc  4128 non-null   float64
# dtypes: float64(1)
# memory usage: 64.5 KB

# %%
california_housing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Initialize the model

model = LinearRegression()

# %%
#Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Make predictions
y_pred = model.predict(X_test)

# %%
#Evaluate model metrics
print(f"Intercept (w0): {model.intercept_}")
print(f"Slope Coefficient (w1): {model.coef_[0]}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
print(f"R-squared Score: {r2_score(y_test, y_pred)}")
# Out:
# Intercept (w0): [0.44459729]
# Slope Coefficient (w1): [0.41933849]
# Mean Squared Error: 0.7091157771765548
# R-squared Score: 0.45885918903846656

# %%
y_test.head()
# Out:
#        MedHouseVal
# 20046      0.47700
# 3024       0.45800
# 15663      5.00001
# 20484      2.18600
# 9814       2.78000

# %%
sns.scatterplot(y = y_test["MedHouseVal"],x = X_test["MedInc"])
# Out:
# <Axes: xlabel='MedInc', ylabel='MedHouseVal'>

# %%
sns.scatterplot(y = y_pred.reshape(-1),x = X_test["MedInc"])
# Out:
# <Axes: xlabel='MedInc'>

# %%
y_pred.T.shape
# Out:
# (1, 4128)

# %%
y_pred.shape
# Out:
# (4128, 1)

# %%
X_test["MedInc"].shape
# Out:
# (4128,)
